# %% [markdown]
# # <p style="align: right; direction: rtl; float: right;">המשך לימוד</p>
#
# <p style="text-align: right; direction: rtl; float: right;">
# מומלץ:
# </p>
#
# <ul style="text-align: right; direction: rtl; float: right;">
#     <li>Flask/FastAPI - בניית אפליקציות web</li>
#     <li>Selenium - אוטומציה של דפדפן</li>
#     <li>BeautifulSoup - web scraping</li>
#     <li>Matplotlib - ויזואליזציה</li>
# </ul>
