# %% [markdown]
# # <p style="align: right; direction: rtl; float: right;">סיימתם את הקורס! 🎓</p>

# %% [markdown]
# ## <p style="align: right; direction: rtl; float: right;">מה למדנו?</p>
#
# <p style="text-align: right; direction: rtl;">
# במהלך 8 הימים למדנו:
# </p>
#
# <ul style="text-align: right; direction: rtl;">
#     <li>✅ <strong>OOP מתקדם</strong> - Classes, Inheritance, Magic Methods</li>
#     <li>✅ <strong>עבודה עם קבצים</strong> - CSV, JSON, Excel (openpyxl)</li>
#     <li>✅ <strong>APIs ותקשורת</strong> - Requests, JSON responses</li>
#     <li>✅ <strong>מסדי נתונים</strong> - SQLite, SQL queries</li>
#     <li>✅ <strong>ניתוח נתונים</strong> - Pandas, DataFrames</li>
#     <li>✅ <strong>אוטומציה</strong> - Email, Threading</li>
#     <li>✅ <strong>פרויקטים משולבים</strong> - כל הנ"ל ביחד!</li>
# </ul>

# %% [markdown]
# ## <p style="align: right; direction: rtl; float: right;">מה הלאה? המלצות ללימוד המשך</p>

# %% [markdown]
# ### <p style="align: right; direction: rtl; float: right;">1. Web Development</p>
#
# <p style="text-align: right; direction: rtl;">
# <strong>Flask / FastAPI</strong> - בניית אפליקציות web ו-APIs
# </p>
#
# <ul style="text-align: right; direction: rtl;">
#     <li>בנו אתרים דינמיים</li>
#     <li>צרו REST APIs משלכם</li>
#     <li>חברו למסדי נתונים</li>
#     <li>אימות משתמשים</li>
# </ul>
#
# <p style="text-align: right; direction: rtl;">
# <strong>משאבים:</strong> flask.palletsprojects.com, fastapi.tiangolo.com
# </p>

# %% [markdown]
# ### <p style="align: right; direction: rtl; float: right;">2. Web Scraping & Automation</p>
#
# <p style="text-align: right; direction: rtl;">
# <strong>BeautifulSoup / Selenium</strong> - איסוף נתונים מאתרים
# </p>
#
# <ul style="text-align: right; direction: rtl;">
#     <li>שליפת מחירים מאתרי מסחר</li>
#     <li>איסוף חדשות ומאמרים</li>
#     <li>אוטומציה של משימות דפדפן</li>
#     <li>בדיקות אוטומטיות</li>
# </ul>

# %% [markdown]
# ### <p style="align: right; direction: rtl; float: right;">3. Data Science & Machine Learning</p>
#
# <p style="text-align: right; direction: rtl;">
# <strong>Matplotlib / Seaborn</strong> - ויזואליזציה של נתונים<br>
# <strong>Scikit-learn</strong> - למידת מכונה
# </p>
#
# <ul style="text-align: right; direction: rtl;">
#     <li>גרפים וויזואליזציות מתקדמות</li>
#     <li>חיזוי מגמות</li>
#     <li>סיווג וקיבוץ נתונים</li>
#     <li>ניתוח סטטיסטי</li>
# </ul>

# %% [markdown]
# ### <p style="align: right; direction: rtl; float: right;">4. Advanced Automation</p>
#
# <ul style="text-align: right; direction: rtl;">
#     <li><strong>Pytest</strong> - בדיקות אוטומטיות לקוד</li>
#     <li><strong>Schedule / APScheduler</strong> - הרצת משימות מתוזמנות</li>
#     <li><strong>Click / Typer</strong> - כלי CLI מקצועיים</li>
#     <li><strong>Docker</strong> - ארגון אפליקציות לקונטיינרים</li>
# </ul>

# %% [markdown]
# ## <p style="align: right; direction: rtl; float: right;">עצות לדרך</p>
#
# <ol style="text-align: right; direction: rtl;">
#     <li><strong>תרגלו כל יום</strong> - גם 15 דקות עושות הבדל</li>
#     <li><strong>בנו פרויקטים אמיתיים</strong> - פתרו בעיות שלכם</li>
#     <li><strong>קראו קוד של אחרים</strong> - GitHub מלא בדוגמאות</li>
#     <li><strong>תרמו לקוד פתוח</strong> - למדו מהקהילה</li>
#     <li><strong>אל תפחדו לטעות</strong> - כל מתכנת נתקע, זה חלק מהתהליך</li>
# </ol>

# %% [markdown]
# ## <p style="align: right; direction: rtl; float: right;">משאבים מומלצים</p>
#
# <ul style="text-align: right; direction: rtl;">
#     <li><strong>Real Python</strong> (realpython.com) - מדריכים מעולים</li>
#     <li><strong>Python Docs</strong> (docs.python.org) - התיעוד הרשמי</li>
#     <li><strong>Stack Overflow</strong> - קהילת עזרה</li>
#     <li><strong>Awesome Python</strong> (github.com/vinta/awesome-python) - רשימת ספריות מומלצות</li>
#     <li><strong>Python Weekly</strong> - ניוזלטר שבועי</li>
# </ul>

# %% [markdown]
# ---
#
# <p style="text-align: center; direction: rtl;">
#     <strong>כל הכבוד! 🎉</strong><br>
#     סיימתם קורס Python מתקדם.<br>
#     עכשיו זה הזמן לבנות משהו מדהים!<br>
#     <br>
#     <em>בהצלחה בהמשך הדרך! 🐍✨</em>
# </p>
