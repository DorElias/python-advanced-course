# %% [markdown]
# # <p style="align: right; direction: rtl; float: right;">פרויקט סיום</p>
#
# <p style="text-align: right; direction: rtl; float: right;">
# בחרו אחד מ-3 הפרויקטים:
# </p>
#
# <ol style="text-align: right; direction: rtl; float: right;">
#     <li>מערכת ניהול מכירות (Excel + SQL + Pandas)</li>
#     <li>מעקב מחירים אוטומטי (Requests + Excel + Email)</li>
#     <li>מערכת עיבוד מיילים (Email + CSV + JSON)</li>
# </ol>
