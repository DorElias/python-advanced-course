# %% [markdown]
# # <p style="align: right; direction: rtl; float: right;">פרויקט סיום - שילוב כל הנלמד</p>

# %% [markdown]
# <p style="text-align: right; direction: rtl;">
# הגיע הזמן לשלב את כל מה שלמדנו בפרויקט אמיתי!<br>
# בחרו אחד מ-3 הפרויקטים הבאים, או שלבו רעיונות מכמה פרויקטים.
# </p>

# %% [markdown]
# ## <p style="align: right; direction: rtl; float: right;">פרויקט 1: מערכת ניהול מכירות מלאה</p>
#
# <p style="text-align: right; direction: rtl;">
# <strong>מה המערכת עושה?</strong>
# </p>
#
# <ul style="text-align: right; direction: rtl;">
#     <li>ניהול מוצרים ומלאי (SQL)</li>
#     <li>רישום מכירות (CSV/Excel)</li>
#     <li>ניתוח נתונים (Pandas)</li>
#     <li>יצירת דוחות Excel מעוצבים</li>
#     <li>שליחת דוח יומי במייל</li>
# </ul>
#
# <p style="text-align: right; direction: rtl;">
# <strong>שלבי הפיתוח:</strong>
# </p>
#
# <ol style="text-align: right; direction: rtl;">
#     <li>בנו מסד נתונים עם טבלאות: products, sales, customers</li>
#     <li>כתבו פונקציות להוספת מכירה, עדכון מלאי</li>
#     <li>צרו דוח Excel עם סטטיסטיקות (מכירות לפי יום/מוצר/לקוח)</li>
#     <li>השתמשו ב-Pandas לניתוח מגמות</li>
#     <li>שלחו דוח יומי במייל עם גרפים</li>
#     <li>(בונוס) הוסיפו התראות על מלאי נמוך</li>
# </ol>

# %%
# התחילו כאן את הפרויקט!

# %% [markdown]
# ## <p style="align: right; direction: rtl; float: right;">פרויקט 2: מעקב מחירים אוטומטי</p>
#
# <p style="text-align: right; direction: rtl;">
# <strong>מה המערכת עושה?</strong>
# </p>
#
# <ul style="text-align: right; direction: rtl;">
#     <li>מעקב אחר מחירי מוצרים באינטרנט (API או web scraping)</li>
#     <li>שמירת היסטוריה ב-SQL</li>
#     <li>ניתוח מגמות (Pandas)</li>
#     <li>התראות במייל כשהמחיר יורד</li>
#     <li>דוח Excel שבועי עם גרפים</li>
# </ul>
#
# <p style="text-align: right; direction: rtl;">
# <strong>שלבי הפיתוח:</strong>
# </p>
#
# <ol style="text-align: right; direction: rtl;">
#     <li>בחרו API (מזג אויר, מטבעות, מניות, קריפטו)</li>
#     <li>שלפו נתונים כל X דקות (threading לבדיקה ברקע)</li>
#     <li>שמרו היסטוריה ב-SQL</li>
#     <li>חשבו ממוצעים נעים, מינימום/מקסימום</li>
#     <li>אם המחיר ירד ביותר מ-5% - שלחו מייל</li>
#     <li>צרו דוח Excel עם טבלת מחירים וסטטיסטיקות</li>
# </ol>

# %%
# התחילו כאן את הפרויקט!

# %% [markdown]
# ## <p style="align: right; direction: rtl; float: right;">פרויקט 3: מערכת עיבוד מיילים ומשימות</p>
#
# <p style="text-align: right; direction: rtl;">
# <strong>מה המערכת עושה?</strong>
# </p>
#
# <ul style="text-align: right; direction: rtl;">
#     <li>קריאת מיילים נכנסים (IMAP)</li>
#     <li>זיהוי סוג המייל (חשבונית, הזמנה, משימה)</li>
#     <li>שמירה במסד נתונים לפי קטגוריה</li>
#     <li>יצירת דוחות Excel</li>
#     <li>שליחת סיכום יומי</li>
# </ul>
#
# <p style="text-align: right; direction: rtl;">
# <strong>שלבי הפיתוח:</strong>
# </p>
#
# <ol style="text-align: right; direction: rtl;">
#     <li>התחברו לתיבת דואר (Gmail IMAP)</li>
#     <li>קראו מיילים חדשים</li>
#     <li>חלצו: נושא, שולח, תאריך, קבצים מצורפים</li>
#     <li>סווגו לפי מילות מפתח ("חשבונית", "הזמנה", וכו')</li>
#     <li>שמרו ב-SQL</li>
#     <li>שמרו קבצים מצורפים בתיקיות</li>
#     <li>צרו דוח Excel יומי של כל המיילים</li>
#     <li>שלחו סיכום במייל</li>
# </ol>

# %%
# התחילו כאן את הפרויקט!

# %% [markdown]
# ---
#
# <p style="text-align: center; direction: rtl;">
#     <strong>טיפים להצלחה:</strong>
# </p>
#
# <ol style="text-align: right; direction: rtl;">
#     <li>תכננו את הפרויקט לפני שמתחילים לכתוב קוד</li>
#     <li>פצלו לשלבים קטנים - בדקו כל שלב לפני שממשיכים</li>
#     <li>השתמשו ב-git לשמירת גרסאות</li>
#     <li>כתבו הערות בקוד - אתם תודו לעצמכם מחר</li>
#     <li>טפלו בשגיאות (try/except)</li>
#     <li>בדקו עם נתונים אמיתיים</li>
# </ol>
#
# <p style="text-align: center; direction: rtl;">
#     <strong>בהצלחה! 🎉</strong>
# </p>
