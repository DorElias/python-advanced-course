# %% [markdown]
# <img src="images/logo.jpg" style="display: block; margin-left: auto; margin-right: auto;" alt="לוגו של מיזם לימוד הפייתון">

# %% [markdown]
# # <p style="align: right; direction: rtl; float: right;">יום 4 - תרגולים וסיכום</p>

# %% [markdown]
# ## <p style="align: right; direction: rtl; float: right;">תרגיל 1: מזג אויר</p>

# %% [markdown]
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# כתבו תוכנית שמקבלת שם עיר מהמשתמש ומציגה:
# </p>
#
# <ol style="text-align: right; direction: rtl; float: right; clear: both;">
#     <li>טמפרטורה נוכחית</li>
#     <li>תיאור מזג האוויר</li>
#     <li>תחזית ל-3 הימים הקרובים</li>
# </ol>
#
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# השתמשו ב-wttr.in או Open-Meteo API
# </p>

# %%
# פתרו כאן:

# %% [markdown]
# ## <p style="align: right; direction: rtl; float: right;">תרגיל 2: ציטוטים אקראיים</p>

# %% [markdown]
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# כתבו תוכנית שמציגה 5 ציטוטים אקראיים מ-quotable.io<br>
# לכל ציטוט הציגו: הטקסט, שם המחבר, תגיות
# </p>

# %%
# פתרו כאן:

# %% [markdown]
# ## <p style="align: right; direction: rtl; float: right;">תרגיל 3: הורדת תמונות</p>

# %% [markdown]
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# כתבו תוכנית שמורידה 10 תמונות של כלבים מ-dog.ceo<br>
# ושומרת אותן בתיקייה dogs/ עם שמות dog_1.jpg, dog_2.jpg וכו'
# </p>

# %%
# פתרו כאן:

# %% [markdown]
# ## <p style="align: right; direction: rtl; float: right;">תרגיל 4: מעקב מחירי מטבע</p>

# %% [markdown]
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# צרו תוכנית שבודקת שער דולר/שקל כל 10 שניות (5 פעמים)<br>
# ושומרת את התוצאות ל-CSV עם: תאריך, שעה, שער<br>
# השתמשו ב-exchangerate-api.com או frankfurter.app
# </p>

# %%
# פתרו כאן:

# %% [markdown]
# ## <p style="align: right; direction: rtl; float: right;">תרגיל 5: מערכת התראות</p>

# %% [markdown]
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# צרו מערכת שבודקת מזג אוויר ושולחת התראה:<br>
# אם הטמפרטורה למחר תהיה מעל 30 מעלות או מתחת ל-10,<br>
# שמרו הודעת התראה לקובץ alerts.txt עם תאריך ושעה
# </p>

# %%
# פתרו כאן:

# %% [markdown]
# ## <p style="align: right; direction: rtl; float: right;">תרגיל 6: פרויקט - מאגר חדשות</p>

# %% [markdown]
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# בנו מערכת שאוספת כותרות חדשות מ-2-3 מקורות:<br>
# - NewsAPI או RSS feeds<br>
# - שמרו לקובץ JSON: תאריך, מקור, כותרת, קישור<br>
# - יצרו דוח Excel עם הכותרות של היום<br>
# - הוסיפו פילטר לפי מילות מפתח ("כלכלה", "טכנולוגיה" וכו')
# </p>

# %%
# פתרו כאן:

# %% [markdown]
# ---
#
# <p style="text-align: center; direction: rtl;">
#     <strong>סיימתם?</strong><br>
#     מחר: SQL - ניהול מסדי נתונים!<br>
#     <em>בהצלחה! 🐍✨</em>
# </p>
