# %% [markdown]
# <img src="images/logo.jpg" style="display: block; margin-left: auto; margin-right: auto;" alt="לוגו של מיזם לימוד הפייתון">

# %% [markdown]
# # <p style="align: right; direction: rtl; float: right;">יום 3 - תרגולים וסיכום</p>

# %% [markdown]
# ## <p style="align: right; direction: rtl; float: right;">תרגיל 1: CSV - עיבוד נתוני מכירות</p>

# %% [markdown]
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# קראו את קובץ sales.csv וחשבו:
# </p>
#
# <ol style="text-align: right; direction: rtl; float: right; clear: both;">
#     <li>המוצר שנמכר בכמות הגדולה ביותר</li>
#     <li>המוצר שהניב הכנסה מקסימלית</li>
#     <li>סך הכנסות לפי קטגוריה</li>
#     <li>מחיר ממוצע למוצר</li>
#     <li>שמרו דוח מסכם ל-CSV חדש עם: קטגוריה, מספר מוצרים, סך הכנסות</li>
# </ol>

# %%
# פתרו כאן:

# %% [markdown]
# ## <p style="align: right; direction: rtl; float: right;">תרגיל 2: JSON - ניהול משתמשים</p>

# %% [markdown]
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# צרו מערכת ניהול משתמשים עם JSON:
# </p>
#
# <ol style="text-align: right; direction: rtl; float: right; clear: both;">
#     <li>פונקציה <code>add_user(username, email, age, preferences)</code></li>
#     <li>פונקציה <code>get_user(username)</code></li>
#     <li>פונקציה <code>update_preference(username, key, value)</code></li>
#     <li>פונקציה <code>get_users_by_age_range(min_age, max_age)</code></li>
#     <li>כל הנתונים נשמרים ב-users.json</li>
#     <li>המבנה: {"users": [{username, email, age, preferences: {}, created_at}]}</li>
# </ol>

# %%
# פתרו כאן:

# %% [markdown]
# ## <p style="align: right; direction: rtl; float: right;">תרגיל 3: Excel - דוח עובדים</p>

# %% [markdown]
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# צרו קובץ Excel עם 2 גליונות:
# </p>
#
# **גליון 1 - עובדים:**
# <ul style="text-align: right; direction: rtl; float: right; clear: both;">
#     <li>עמודות: שם, מחלקה, שכר בסיס, בונוס (%), סה"כ שכר</li>
#     <li>10 עובדים (תנו ערכים)</li>
#     <li>עמודת "סה"כ שכר" = נוסחה: שכר בסיס * (1 + בונוס/100)</li>
#     <li>שורת סיכום בתחתית</li>
#     <li>עיצוב: כותרות בצבע, מסגרות, יישור</li>
# </ul>
#
# **גליון 2 - סיכום:**
# <ul style="text-align: right; direction: rtl; float: right; clear: both;">
#     <li>שכר ממוצע</li>
#     <li>שכר מקסימלי ומינימלי</li>
#     <li>מספר עובדים לפי מחלקה</li>
# </ul>

# %%
# פתרו כאן:

# %% [markdown]
# ## <p style="align: right; direction: rtl; float: right;">תרגיל 4: המרות - CSV ↔ JSON ↔ Excel</p>

# %% [markdown]
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# כתבו 3 פונקציות המרה:
# </p>
#
# <ol style="text-align: right; direction: rtl; float: right; clear: both;">
#     <li><code>csv_to_json(csv_file, json_file)</code></li>
#     <li><code>json_to_excel(json_file, excel_file)</code></li>
#     <li><code>excel_to_csv(excel_file, csv_file, sheet_name)</code></li>
# </ol>
#
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# בדקו על employees.csv:
# </p>
#
# ```
# employees.csv → employees.json → employees_new.xlsx → employees_final.csv
# ```

# %%
# פתרו כאן:

# %% [markdown]
# ## <p style="align: right; direction: rtl; float: right;">תרגיל 5: פרויקט - מערכת ניהול מלאי</p>

# %% [markdown]
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# בנו מערכת מלאי עם 3 פורמטים:
# </p>
#
# **קובץ products.json:**
# ```json
# {
#   "products": [
#     {"id": 1, "name": "...", "category": "...", "price": 100, "stock": 50}
#   ]
# }
# ```
#
# **פונקציות:**
# <ul style="text-align: right; direction: rtl; float: right; clear: both;">
#     <li><code>add_product(name, category, price, stock)</code></li>
#     <li><code>update_stock(product_id, quantity)</code> - חיובי/שלילי</li>
#     <li><code>get_low_stock(threshold)</code></li>
#     <li><code>export_to_csv(filename)</code></li>
#     <li><code>export_to_excel(filename)</code> - עם עיצוב + גליון סיכום</li>
#     <li><code>generate_report()</code> - Excel מפואר עם נוסחאות</li>
# </ul>

# %%
# פתרו כאן:

# %% [markdown]
# ## <p style="align: right; direction: rtl; float: right;">תרגיל 6: Excel מתקדם - חשבונית</p>

# %% [markdown]
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# צרו חשבונית מעוצבת ב-Excel:
# </p>
#
# **מבנה:**
# <ul style="text-align: right; direction: rtl; float: right; clear: both;">
#     <li>כותרת: "חשבונית מס' XXX" - גדול, מרכז, צבע רקע</li>
#     <li>פרטי לקוח: שם, כתובת, ת.ז</li>
#     <li>טבלת פריטים: מוצר, כמות, מחיר יחידה, סה"כ (נוסחה)</li>
#     <li>חישובים בתחתית:</li>
#     <ul>
#         <li>סכום ביניים</li>
#         <li>הנחה (%) - נוסחה</li>
#         <li>לפני מע"מ</li>
#         <li>מע"מ 17% - נוסחה</li>
#         <li>סה"כ לתשלום - בולט</li>
#     </ul>
#     <li>עיצוב מלא: צבעים, גבולות, פונטים, יישור</li>
# </ul>

# %%
# פתרו כאן:

# %% [markdown]
# ---
#
# <p style="text-align: center; direction: rtl;">
#     <strong>סיימתם?</strong><br>
#     מחר: Requests ו-APIs - תקשורת עם האינטרנט!<br>
#     <em>בהצלחה! 🐍✨</em>
# </p>
