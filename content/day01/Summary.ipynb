# %% [markdown]
# <img src="images/logo.jpg" style="display: block; margin-left: auto; margin-right: auto;" alt="לוגו של מיזם לימוד הפייתון">

# %% [markdown]
# # <p style="align: right; direction: rtl; float: right;">יום 1 - תרגולים וסיכום</p>

# %% [markdown]
# <p style="text-align: right; direction: rtl; float: right;">
# הגיע הזמן לתרגל! פתרו את התרגילים הבאים בעצמכם.<br>
# נסו לפתור ללא לחזור למחברות - זה יעזור לכם לבדוק שהבנתם את החומר.
# </p>

# %% [markdown]
# ## <p style="align: right; direction: rtl; float: right;">תרגיל 1: עבודה עם מילונים ורשימות</p>

# %% [markdown]
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# צרו מערכת לניהול מלאי חנות.<br>
# כל מוצר הוא מילון עם: שם, מחיר, כמות במלאי.<br>
# </p>
#
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# <strong>דרישות:</strong>
# </p>
# <ol style="text-align: right; direction: rtl; float: right; clear: both;">
#     <li>צרו רשימה של 5 מוצרים</li>
#     <li>הדפיסו את כל המוצרים שהמחיר שלהם מעל 100 ש"ח</li>
#     <li>חשבו את סך הערך של כל המלאי (מחיר × כמות)</li>
#     <li>מצאו את המוצר היקר ביותר</li>
#     <li>הדפיסו את שמות כל המוצרים שנגמר המלאי שלהם (כמות = 0)</li>
# </ol>

# %%
# פתרו כאן:

# %% [markdown]
# ## <p style="align: right; direction: rtl; float: right;">תרגיל 2: פונקציות עם פרמטרים</p>

# %% [markdown]
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# כתבו פונקציה <code>calculate_discount(price, discount_percent=10, min_price=0)</code> ש:
# </p>
#
# <ol style="text-align: right; direction: rtl; float: right; clear: both;">
#     <li>מקבלת מחיר, אחוז הנחה (ברירת מחדל 10%), ומחיר מינימלי להחלת הנחה</li>
#     <li>מחזירה את המחיר אחרי הנחה רק אם המחיר המקורי גבוה מ-min_price</li>
#     <li>אחרת, מחזירה את המחיר המקורי</li>
#     <li>גם מחזירה הודעה (string) האם ההנחה הוחלה או לא</li>
# </ol>
#
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# <strong>דוגמאות לשימוש:</strong>
# </p>
#
# ```python
# price, msg = calculate_discount(150)  # 135, "הנחה הוחלה"
# price, msg = calculate_discount(150, 20)  # 120, "הנחה הוחלה"
# price, msg = calculate_discount(50, min_price=100)  # 50, "המחיר נמוך מדי"
# ```

# %%
# פתרו כאן:

# %% [markdown]
# ## <p style="align: right; direction: rtl; float: right;">תרגיל 3: עבודה עם *args ו-**kwargs</p>

# %% [markdown]
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# כתבו פונקציה <code>create_report(title, *data_points, **metadata)</code> ש:
# </p>
#
# <ol style="text-align: right; direction: rtl; float: right; clear: both;">
#     <li>מקבלת כותרת (חובה)</li>
#     <li>מקבלת כמה שרוצים נקודות מידע (מספרים)</li>
#     <li>מקבלת מטה-דטה בצורת key=value (שם מחבר, תאריך, וכו')</li>
#     <li>מדפיסה דוח מעוצב עם:</li>
#     <ul>
#         <li>הכותרת</li>
#         <li>כל המטה-דטה</li>
#         <li>סכום נקודות המידע</li>
#         <li>ממוצע נקודות המידע</li>
#         <li>מקסימום ומינימום</li>
#     </ul>
# </ol>
#
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# <strong>דוגמה לשימוש:</strong>
# </p>
#
# ```python
# create_report(
#     "דוח מכירות חודשי",
#     1200, 1500, 1800, 2000, 1700,
#     author="דני כהן",
#     date="01/01/2024",
#     department="מכירות"
# )
# ```

# %%
# פתרו כאן:

# %% [markdown]
# ## <p style="align: right; direction: rtl; float: right;">תרגיל 4: עבודה עם קבצים</p>

# %% [markdown]
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# כתבו תוכנית שמנהלת רשימת משימות עם קובץ:
# </p>
#
# <ol style="text-align: right; direction: rtl; float: right; clear: both;">
#     <li>פונקציה <code>add_task(task_file, task_text)</code> - מוסיפה משימה לקובץ</li>
#     <li>פונקציה <code>read_tasks(task_file)</code> - קוראת את כל המשימות ומחזירה רשימה</li>
#     <li>פונקציה <code>count_tasks(task_file)</code> - מחזירה כמה משימות יש</li>
#     <li>פונקציה <code>clear_completed(task_file)</code> - מוחקת משימות שמתחילות ב-"[✓]"</li>
# </ol>
#
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# פורמט הקובץ: כל שורה = משימה אחת<br>
# דוגמה:
# </p>
#
# ```
# לקנות חלב
# [✓] לשלם חשבונות
# להתקשר לדני
# [✓] לסיים פרויקט
# ```

# %%
# פתרו כאן:

# %% [markdown]
# ## <p style="align: right; direction: rtl; float: right;">תרגיל 5: מודולים - datetime</p>

# %% [markdown]
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# כתבו פונקציה <code>get_work_days(start_date, end_date)</code> ש:
# </p>
#
# <ol style="text-align: right; direction: rtl; float: right; clear: both;">
#     <li>מקבלת תאריך התחלה וסיום (בפורמט "DD/MM/YYYY")</li>
#     <li>מחשבת כמה ימי עבודה (א'-ה') יש בין התאריכים</li>
#     <li>מדפיסה את כל התאריכים שהם ימי שישי בטווח</li>
#     <li>מחזירה tuple של: (ימי עבודה, סופי שבוע, ימי שישי)</li>
# </ol>
#
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# <strong>טיפ:</strong> השתמשו ב-<code>datetime.strptime()</code> להמרת string לתאריך.<br>
# <code>weekday()</code> מחזיר 0-6 (0=Monday, 6=Sunday)
# </p>

# %%
# פתרו כאן:

# %% [markdown]
# ## <p style="align: right; direction: rtl; float: right;">תרגיל 6: מודולים - collections.Counter</p>

# %% [markdown]
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# כתבו פונקציה <code>analyze_text(text)</code> ש:
# </p>
#
# <ol style="text-align: right; direction: rtl; float: right; clear: both;">
#     <li>מקבלת טקסט</li>
#     <li>מדפיסה את 5 המילים הנפוצות ביותר</li>
#     <li>מדפיסה את 3 האותיות הנפוצות ביותר (ללא רווחים)</li>
#     <li>מחזירה מילון עם סטטיסטיקות: מספר מילים, מספר תווים, מספר שורות</li>
# </ol>
#
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# <strong>טיפ:</strong> השתמשו ב-<code>Counter</code> מהמודול <code>collections</code>
# </p>

# %%
# פתרו כאן:

# דוגמה לבדיקה:
sample_text = """
פייתון היא שפת תכנות מעולה.
פייתון קלה ללימוד וחזקה מאוד.
הרבה אנשים אוהבים את פייתון.
"""

# analyze_text(sample_text)

# %% [markdown]
# ## <p style="align: right; direction: rtl; float: right;">תרגיל 7: פרויקט משולב - מערכת ניהול הוצאות</p>

# %% [markdown]
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# בנו מערכת לניהול הוצאות חודשיות. המערכת צריכה לכלול:
# </p>
#
# <ol style="text-align: right; direction: rtl; float: right; clear: both;">
#     <li>פונקציה <code>add_expense(date, category, amount, description="")</code></li>
#     <li>פונקציה <code>get_expenses_by_category(category)</code></li>
#     <li>פונקציה <code>get_expenses_by_month(month, year)</code></li>
#     <li>פונקציה <code>get_total_by_category()</code> - מחזירה מילון של סכומים לכל קטגוריה</li>
#     <li>פונקציה <code>get_summary()</code> - מדפיסה סיכום מפורט</li>
#     <li>פונקציה <code>save_to_file(filename)</code> - שומרת את כל ההוצאות לקובץ</li>
#     <li>פונקציה <code>load_from_file(filename)</code> - טוענת הוצאות מקובץ</li>
# </ol>
#
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# שמרו את כל ההוצאות ברשימה גלובלית, או בתור מחלקה.<br>
# השתמשו במודולים datetime, collections, ובכל מה שלמדנו היום!
# </p>

# %%
# פתרו כאן:

# %% [markdown]
# ## <p style="align: right; direction: rtl; float: right;">בונוס: תרגיל אתגר 🏆</p>

# %% [markdown]
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# כתבו מערכת לניהול תורים (queue) לבנק/משרד ממשלתי:
# </p>
#
# <ol style="text-align: right; direction: rtl; float: right; clear: both;">
#     <li>לקוח יכול להצטרף לתור ומקבל מספר תור</li>
#     <li>לקוח יכול לבדוק מה המיקום שלו בתור</li>
#     <li>פקיד יכול לקרוא ללקוח הבא</li>
#     <li>המערכת מחשבת זמן המתנה משוער (2 דקות ללקוח)</li>
#     <li>יש עדיפות ללקוחות מעל גיל 65 או נכים (מקבלים מספרים קטנים יותר)</li>
#     <li>המערכת שומרת לוג של כל האירועים (מי הצטרף, מי שורת, וכו') עם timestamps</li>
#     <li>בסוף היום אפשר להדפיס דוח: כמה לקוחות שורתו, זמן ממוצע, שעת עומס וכו'</li>
# </ol>
#
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# השתמשו ב-datetime, collections.deque, ובכל מה שלמדנו!
# </p>

# %%
# פתרו כאן:

# %% [markdown]
# ---
#
# <p style="text-align: center; direction: rtl;">
#     <strong>סיימתם?</strong><br>
#     מעולה! מחר נתחיל עם OOP מעמיק.<br>
#     <em>בהצלחה! 🐍✨</em>
# </p>
