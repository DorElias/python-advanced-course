# %% [markdown]
# # <p style="align: right; direction: rtl; float: right;">יום 7 - תרגולים</p>

# %% [markdown]
# ## <p style="align: right; direction: rtl; float: right;">תרגיל 1: שליחת דוח יומי</p>
#
# <p style="text-align: right; direction: rtl;">
# כתבו תוכנית ששולחת מייל עם דוח מכירות:<br>
# - קראו CSV של מכירות<br>
# - חשבו סטטיסטיקות (סכום, ממוצע)<br>
# - שלחו מייל עם התוצאות
# </p>

# %% [markdown]
# ## <p style="align: right; direction: rtl; float: right;">תרגיל 2: הורדה מקבילית</p>
#
# <p style="text-align: right; direction: rtl;">
# כתבו תוכנית שמורידה 10 תמונות מ-APIs שונים במקביל:<br>
# - השתמשו ב-threading<br>
# - שמרו את התמונות<br>
# - הציגו כמה זמן חסכתם לעומת הורדה רגילה
# </p>

# %% [markdown]
# ## <p style="align: right; direction: rtl; float: right;">תרגיל 3: מערכת התראות</p>
#
# <p style="text-align: right; direction: rtl;">
# בנו מערכת שבודקת מחירי מניות (או מזג אוויר) כל 10 דקות:<br>
# - אם המחיר עבר סף מסוים - שלחו מייל<br>
# - השתמשו ב-threading לבדיקה רקע<br>
# - שמרו לוג של הבדיקות ב-CSV
# </p>

# %% [markdown]
# ## <p style="align: right; direction: rtl; float: right;">תרגיל 4: שליפת נתונים אסינכרונית</p>
#
# <p style="text-align: right; direction: rtl;">
# כתבו תוכנית אסינכרונית ששולפת מידע על 10 מדינות מ-REST Countries API:<br>
# - השתמשו ב-asyncio ו-aiohttp<br>
# - שלפו במקביל את כל המדינות<br>
# - הדפיסו: שם, אוכלוסייה, בירה<br>
# - השוו את זמן הריצה לגישה רגילה (requests)
# </p>
#
# <p style="text-align: right; direction: rtl;">
# API: https://restcountries.com/v3.1/name/{country_name}
# </p>

# %% [markdown]
# ## <p style="align: right; direction: rtl; float: right;">תרגיל 5: הורדת קבצים אסינכרונית</p>
#
# <p style="text-align: right; direction: rtl;">
# כתבו תוכנית שמורידה 20 תמונות מ-Lorem Picsum במקביל:<br>
# - השתמשו ב-asyncio<br>
# - שמרו כל תמונה בשם image_1.jpg, image_2.jpg וכו'<br>
# - הדפיסו התקדמות ("הורדה 1/20", "הורדה 2/20"...)<br>
# - מדדו כמה זמן חסכתם לעומת הורדה רגילה
# </p>
#
# <p style="text-align: right; direction: rtl;">
# URL: https://picsum.photos/400/300?random={num}
# </p>

# %% [markdown]
# ## <p style="align: right; direction: rtl; float: right;">תרגיל 6: משימות עם timeout</p>
#
# <p style="text-align: right; direction: rtl;">
# כתבו פונקציה אסינכרונית שמדמה משימה ארוכה (sleep אקראי 1-5 שניות):<br>
# - הריצו 5 משימות כאלה במקביל<br>
# - הגדירו timeout של 3 שניות<br>
# - הדפיסו אילו משימות הצליחו ואילו עברו timeout<br>
# - השתמשו ב-asyncio.wait_for()
# </p>
