# %% [markdown]
# <img src="images/logo.jpg" style="display: block; margin-left: auto; margin-right: auto;" alt="לוגו הקורס">

# %% [markdown]
# # <p style="text-align: right; direction: rtl; float: right;">יום 7 - תרגולים</p>

# %% [markdown]
# ## <p style="text-align: right; direction: rtl; float: right; clear: both;">תרגיל 1: שליחת דוח יומי</p>

# %% [markdown]
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# כתבו תוכנית ששולחת מייל עם דוח מכירות:
# </p>
#
# <ul style="text-align: right; direction: rtl; float: right; clear: both;">
#     <li>קראו CSV של מכירות</li>
#     <li>חשבו סטטיסטיקות (סכום, ממוצע)</li>
#     <li>שלחו מייל עם התוצאות</li>
# </ul>

# %% [markdown]
# ## <p style="text-align: right; direction: rtl; float: right; clear: both;">תרגיל 2: הורדה מקבילית</p>

# %% [markdown]
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# כתבו תוכנית שמורידה 10 תמונות מ-APIs שונים במקביל:
# </p>
#
# <ul style="text-align: right; direction: rtl; float: right; clear: both;">
#     <li>השתמשו ב-threading</li>
#     <li>שמרו את התמונות</li>
#     <li>הציגו כמה זמן חסכתם לעומת הורדה רגילה</li>
# </ul>

# %% [markdown]
# ## <p style="text-align: right; direction: rtl; float: right; clear: both;">תרגיל 3: מערכת התראות</p>

# %% [markdown]
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# בנו מערכת שבודקת מחירי מניות (או מזג אוויר) כל 10 דקות:
# </p>
#
# <ul style="text-align: right; direction: rtl; float: right; clear: both;">
#     <li>אם המחיר עבר סף מסוים - שלחו מייל</li>
#     <li>השתמשו ב-threading לבדיקה ברקע</li>
#     <li>שמרו לוג של הבדיקות ב-CSV</li>
# </ul>

# %% [markdown]
# ## <p style="text-align: right; direction: rtl; float: right; clear: both;">תרגיל 4: שליפת נתונים אסינכרונית</p>

# %% [markdown]
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# כתבו תוכנית אסינכרונית ששולפת מידע על 10 מדינות מ-REST Countries API:
# </p>
#
# <ul style="text-align: right; direction: rtl; float: right; clear: both;">
#     <li>השתמשו ב-asyncio ו-aiohttp</li>
#     <li>שלפו במקביל את כל המדינות</li>
#     <li>הדפיסו: שם, אוכלוסייה, בירה</li>
#     <li>השוו את זמן הריצה לגישה רגילה (requests)</li>
# </ul>
#
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# API: <code>https://restcountries.com/v3.1/name/{country_name}</code>
# </p>

# %% [markdown]
# ## <p style="text-align: right; direction: rtl; float: right; clear: both;">תרגיל 5: הורדת קבצים אסינכרונית</p>

# %% [markdown]
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# כתבו תוכנית שמורידה 20 תמונות מ-Lorem Picsum במקביל:
# </p>
#
# <ul style="text-align: right; direction: rtl; float: right; clear: both;">
#     <li>השתמשו ב-asyncio</li>
#     <li>שמרו כל תמונה בשם image_1.jpg, image_2.jpg וכו'</li>
#     <li>הדפיסו התקדמות ("הורדה 1/20", "הורדה 2/20"...)</li>
#     <li>מדדו כמה זמן חסכתם לעומת הורדה רגילה</li>
# </ul>
#
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# URL: <code>https://picsum.photos/400/300?random={num}</code>
# </p>

# %% [markdown]
# ## <p style="text-align: right; direction: rtl; float: right; clear: both;">תרגיל 6: משימות עם timeout</p>

# %% [markdown]
# <p style="text-align: right; direction: rtl; float: right; clear: both;">
# כתבו פונקציה אסינכרונית שמדמה משימה ארוכה (sleep אקראי 1-5 שניות):
# </p>
#
# <ul style="text-align: right; direction: rtl; float: right; clear: both;">
#     <li>הריצו 5 משימות כאלה במקביל</li>
#     <li>הגדירו timeout של 3 שניות</li>
#     <li>הדפיסו אילו משימות הצליחו ואילו עברו timeout</li>
#     <li>השתמשו ב-<code>asyncio.wait_for()</code></li>
# </ul>
